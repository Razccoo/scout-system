# %%
# %load_ext autoreload
# %autoreload 2

# %%
import soccerdata as sd
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
# Out:
# [08/13/24 16:50:20] INFO     No custom team name replacements found. You can configure these in       ]8;id=305357;file://c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=720539;file://c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\soccerdata\_config.py#90\90]8;;\
#                              C:\Users\Asus\soccerdata\config\teamname_replacements.json.
#                     INFO     Custom league dict loaded from                                          ]8;id=70790;file://c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=229654;file://c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\soccerdata\_config.py#194\194]8;;\
#                              C:\Users\Asus\soccerdata\config\league_dict.json.

# %%
ws = sd.WhoScored(leagues="TUR-Super Lig", seasons=2024)
# Out:
# [08/13/24 17:01:36] INFO     Saving cached data to C:\Users\Asus\soccerdata\data\WhoScored           ]8;id=798219;file://c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=327430;file://c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\soccerdata\_common.py#263\263]8;;\

# %%
loader = ws.read_events(match_id=[1842903, 1842905], output_fmt='loader', force_cache=True)
# Out:
# [08/13/24 17:02:13] INFO     Retrieving calendar for TUR-Super Lig 2425                            ]8;id=599311;file://c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\soccerdata\whoscored.py\whoscored.py]8;;\:]8;id=312172;file://c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\soccerdata\whoscored.py#371\371]8;;\
#                     INFO     [1/11] Retrieving fixtures for TUR-Super Lig 2425                     ]8;id=150118;file://c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\soccerdata\whoscored.py\whoscored.py]8;;\:]8;id=75650;file://c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\soccerdata\whoscored.py#400\400]8;;\
# ...

# %%
events = loader.events(1842905)

# %%
events.keys()
# Out:
# Index(['game_id', 'event_id', 'period_id', 'team_id', 'player_id', 'type_id',
#        'timestamp', 'minute', 'second', 'outcome', 'start_x', 'start_y',
#        'end_x', 'end_y', 'qualifiers', 'related_player_id', 'touch', 'goal',
#        'shot', 'type_name'],
#       dtype='object')
